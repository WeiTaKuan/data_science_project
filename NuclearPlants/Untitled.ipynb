# %%
import pandas as pd
import numpy as np
import statsmodels.api

# %%
data = pd.read_csv("assets/nuclear_power_planst.csv")
data.tail()
# Out:
#    LOCATION     INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 38      SVN  NUCLEARPLANT     TOT     NBR         A  2014      1        NaN
# 39      ZAF  NUCLEARPLANT     TOT     NBR         A  2014      2        NaN
# 40      WLD  NUCLEARPLANT     TOT     NBR         A  2014    438        NaN
# 41     OECD  NUCLEARPLANT     TOT     NBR         A  2014    324        NaN
# 42     EU28  NUCLEARPLANT     TOT     NBR         A  2014    131        NaN

# %%
data.shape
# Out:
# (43, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    43 non-null     object
#  1   INDICATOR   43 non-null     object
#  2   SUBJECT     43 non-null     object
#  3   MEASURE     43 non-null     object
#  4   FREQUENCY   43 non-null     object
#  5   TIME        43 non-null     int64
#  6   Value       43 non-null     int64
#  7   Flag Codes  17 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 2.8+ KB

# %%
data.describe(include='all')
# Out:
#        LOCATION     INDICATOR SUBJECT MEASURE FREQUENCY    TIME       Value  \
# count        43            43      43      43        43    43.0   43.000000
# unique       43             1       1       1         1     NaN         NaN
# top         AUS  NUCLEARPLANT     TOT     NBR         A     NaN         NaN
# freq          1            43      43      43        43     NaN         NaN
# mean        NaN           NaN     NaN     NaN       NaN  2014.0   30.209302
# std         NaN           NaN     NaN     NaN       NaN     0.0   83.651362
# min         NaN           NaN     NaN     NaN       NaN  2014.0    0.000000
# 25%         NaN           NaN     NaN     NaN       NaN  2014.0    0.000000
# 50%         NaN           NaN     NaN     NaN       NaN  2014.0    2.000000
# 75%         NaN           NaN     NaN     NaN       NaN  2014.0   17.500000
# max         NaN           NaN     NaN     NaN       NaN  2014.0  438.000000
#
#        Flag Codes
# count          17
# ...
